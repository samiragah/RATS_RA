# %%
# locust_baseline
# this is for base line testing with Locust

from locust import HttpUser, task, between

class MonolithicUser(HttpUser):
    host = "http://localhost:8002"  # ← پورت baseline
    wait_time = between(1, 3)
    
    @task
    def request_signal_mono(self):
        self.client.post("/request-signal-mono", json={"symbol": "AAPL", "interval": "1h"})
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 # locust_baseline
#       2 # this is for base line testing with Locust
# ----> 4 from locust import HttpUser, task, between
#       6 class MonolithicUser(HttpUser):
#       7     host = "http://localhost:8002"  # ← پورت baseline
#
# File ~\AppData\Roaming\Python\Python311\site-packages\locust\__init__.py:16
#      13 if not os.getenv("LOCUST_SKIP_MONKEY_PATCH", None):
#      14     from gevent import monkey, queue
# ---> 16     monkey.patch_all()
#      18     if not os.getenv("LOCUST_SKIP_URLLIB3_PATCH", None):
#      19         import urllib3
#
# File ~\AppData\Roaming\Python\Python311\site-packages\gevent\monkey\__init__.py:683, in patch_all(socket, dns, time, select, thread, os, ssl, subprocess, sys, aggressive, Event, builtins, signal, queue, contextvars, **kwargs)
#     680 for k, v in modules_to_patch.items():
#     681     locals()[k] = v
# --> 683 from gevent import events
#     684 try:
#     685     _notify_patch(events.GeventWillPatchAllEvent(modules_to_patch, kwargs), _warnings)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\gevent\events.py:75
#      72 from zope.interface import Attribute
#      73 from zope.interface import implementer
# ---> 75 from zope.event import subscribers
#      76 from zope.event import notify
#      80 #: Applications may register for notification of events by appending a
#      81 #: callable to the ``subscribers`` list.
#      82 #:
#    (...)
#      89 #: This is an alias for `zope.event.subscribers`; prefer to use
#      90 #: that attribute directly.
#
# ModuleNotFoundError: No module named 'zope.event'
